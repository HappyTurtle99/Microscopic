# %%
import numpy as np
import matplotlib.pyplot as plt

occc = np.load('stepcheck/occc.npy')

plt.plot(occc)

# %%
r = np.load('stepcheck/chemo_rates1_sim.npy')
plt.plot(r)

# %%
sample_weights = np.load('stepcheck/sample_weights.npy')
plt.plot(sample_weights)

# %%
rt = np.load('stepcheck/chemo_rate_tree1_sim.npy')

plt.plot(rt)
len(rt)
# Out:
# 1024

# %%
counter = 0
for e in rt:
    if e != 0.0:
        print(e, counter + 1)
    counter += 1
# Out:
# 0.7615941559557649 1
# 0.761594155955768 2
# 0.29131261245159096 3
# 1.0529067684073605 4
# 0.2913126124515931 6
# 1.6355319933105363 8
# 4.107825191113079e-15 10
# 0.3799489622552249 11
# 0.67126157470682 12
# 0.2913126124515914 14
# 2.5981061804689647 16
# 0.3799489622552249 17
# 0.47961695688018036 18
# 0.47961695688018047 20
# 0.09966799462495582 21
# 0.4796169568801795 22
# 0.9592339137603789 24
# 0.7162978701990245 25
# 1.516796891959657 26
# 1.516796891959662 28
# 0.6043677771171636 29
# 1.1414173441152011 30
# 6.2155543303040615 32
# 0.7615941559557649 33
# 1.0529067684073588 34
# 1.657274545524527 36
# 2.581268532253489e-15 38
# 0.6043677771171636 39
# 3.1469939708439223 40
# -2.6367796834847468e-15 42
# 0.8004990217606297 43
# 1.0918116342122182 44
# 8.604228440844963e-16 46
# 0.197375320224904 47
# 4.4361809252810565 48
# 0.5370495669980353 49
# 0.8283621794496312 50
# 0.828362179449636 52
# 0.09966799462495582 53
# 0.2970433148498581 54
# 1.587522651559501 56
# ...

# %%
counter = 0
for e in r:
    if e != 0.0:
        print(e, counter + 1)
    counter += 1
# Out:
# 0.7615941559557649 1
# 0.29131261245159096 3
# 0.29131261245159096 6
# 0.29131261245159096 8
# 0.3799489622552249 11
# 0.29131261245159096 12
# 0.29131261245159096 14
# 0.3799489622552249 17
# 0.09966799462495582 18
# 0.09966799462495582 21
# 0.3799489622552249 22
# 0.7162978701990245 25
# 0.8004990217606297 26
# 0.6043677771171636 29
# 0.5370495669980353 30
# 0.7615941559557649 33
# 0.29131261245159096 34
# 0.6043677771171636 36
# 0.6043677771171636 39
# 0.8853516482022625 40
# 0.8004990217606297 43
# 0.29131261245159096 44
# 0.197375320224904 47
# 0.5370495669980353 49
# 0.29131261245159096 50
# 0.09966799462495582 53
# 0.197375320224904 54
# 0.46211715726000974 56
# 0.5370495669980353 61
# 0.197375320224904 63
# 0.197375320224904 65
# 0.197375320224904 66
# 0.5370495669980353 68
# 0.5370495669980353 71
# 0.46211715726000974 72
# 0.6043677771171636 75
# 0.46211715726000974 76
# 0.197375320224904 79
# 0.3799489622552249 81
# 0.8336546070121553 82
# 0.6043677771171636 85
# ...

# %%
counter = 0
for e in sample_weights:
    if e != 0.0:
        print(e, counter + 1)
    counter += 1
# Out:
# 109.0 1
# 52.0 3
# 43.0 6
# 52.0 8
# 42.0 11
# 47.0 12
# 39.0 14
# 57.0 17
# 14.0 18
# 13.0 21
# 76.0 22
# 120.0 25
# 128.0 26
# 97.0 29
# 85.0 30
# 109.0 33
# 48.0 34
# 102.0 36
# 99.0 39
# 157.0 40
# 110.0 43
# 44.0 44
# 19.0 47
# 85.0 49
# 51.0 50
# 15.0 53
# 34.0 54
# 75.0 56
# 95.0 61
# 29.0 63
# 30.0 65
# 31.0 66
# 93.0 68
# 88.0 71
# 79.0 72
# 88.0 75
# 84.0 76
# 27.0 79
# 61.0 81
# 125.0 82
# 112.0 85
# 75.0 88
# 73.0 91
# 91.0 92
# 40.0 94
# 112.0 97
# 89.0 101
# 43.0 102
# 15.0 104
# 105.0 106
# 49.0 109
# 55.0 111
# 76.0 113
# 85.0 114
# 46.0 117
# 81.0 118
# 37.0 121
# 64.0 123
# 122.0 124
# 30.0 127
# 37.0 129
# 35.0 130
# 37.0 133
# 15.0 135
# 92.0 136
# 118.0 139
# 68.0 140
# 32.0 143
# 40.0 145
# 10.0 147
# 66.0 148
# 92.0 151
# 150.0 152
# 126.0 155
# 57.0 157
# 26.0 158
# 104.0 162
# 23.0 165
# 71.0 167
# 42.0 169
# 26.0 171
# 157.0 172
# 126.0 175
# 56.0 176
# 62.0 178
# 122.0 181
# 14.0 182
# 112.0 184
# 116.0 187
# 29.0 189
# 157.0 190
# 127.0 193
# 15.0 195
# ...

# %%
i = 2141
for j in range(7):
    i = i+ (i & -i)
    print(i)

# i = 2142
# for j in range(7):
#     i = i+ (i & -i)
#     print(i)

i = 2145
for j in range(7):
    i = i+ (i & -i)
    print(i)
# Out:
# 2142
# 2144
# 2176
# 2304
# 2560
# 3072
# 4096
# 2146
# 2148
# 2152
# 2160
# 2176
# 2304
# 2560
