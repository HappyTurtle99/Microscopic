# %%
from helper_functions import *
directory = '/scratch.local/gtucci/micro/julia/l1_25.00_Dn1_0.80_T_100.00_2026-04-11_094043'
occupancies_t, tau_t, cache, chemo_rates = load_sim(directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from helper_functions import *
#       3 directory = '/scratch.local/gtucci/micro/julia/l1_25.00_Dn1_0.80_T_100.00_2026-04-11_094043'
# ----> 4 occupancies_t, tau_t, cache, chemo_rates = load_sim(directory)
#
# File ~/Work/DiscreteChemo/DiscreteChemo/Microscopic/helper_functions.py:446, in <genexpr>(.0)
#     444 def load_sim(dir):
#     445     names_in_order = ['occupancies_t.npy', 'tau_t.npy', 'cache.npy', 'chemo_rates.npy']
# --> 446     return (np.load(os.path.join(dir, file)) for file in names_in_order)
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
# ...

# %%
plot_results(occupancies_t, tau_t, 12, 0.9, 1, Nlines=5)
