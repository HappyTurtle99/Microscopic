# %%
! julia110 --project=. mastereq_sim.jl 0 0 1
# Out:
# zsh:1: command not found: julia110

# %%
from helper_functions import *
directory = '/Users/sarce/Microscopic/l1_0.00_Dn1_0.00_T_1.00_2026-04-15_165456'
occupancies_t, tau_t, cache, chemo_rates1, chemo_rates2 = load_sim(directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from helper_functions import *
#       2 directory = '/Users/sarce/Microscopic/l1_0.00_Dn1_0.00_T_1.00_2026-04-15_165456'
# ----> 3 occupancies_t, tau_t, cache, chemo_rates1, chemo_rates2 = load_sim(directory)
#
# File ~/Microscopic/helper_functions.py:447, in <genexpr>(.0)
#     445 def load_sim(dir):
#     446     names_in_order = ['occupancies_t.npy', 'tau_t.npy', 'cache.npy', 'chemo_rates1.npy', 'chemo_rates2.npy']
# --> 447     return (np.load(os.path.join(dir, file)) for file in names_in_order)
#
# File ~/Microscopic/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
# ...

# %%
plot_results(occupancies_t, tau_t, 12, 0, 1, Nlines=5)
